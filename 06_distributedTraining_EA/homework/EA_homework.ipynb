# %% [markdown]
# ## Summary:
#
# The modified tensorflow2_mnist_hvd.py code works for -n 1, produces results for -n 2, and gives errors for -n > 2. The accuracy plots look bad for -n 2. HDV was not correctly implemented.

# %%
# !pwd
# Out:
# /home/earaya/ai-science-training-series_WORK_ON_WH_6_NOT_SUBMITTED/06_distributedTraining_EA/homework

# %%
# !ls
# Out:
# 10113346.cobaltlog  accuracy_2.pdf     README.md
# 10113347.cobaltlog  checkpoints        tensorflow2_mnist_hvd.py
# 10113352.cobaltlog  EA_homework.ipynb  tensorflow2_mnist_hvd.py~
# 10113416.cobaltlog  metrics.dat        tensorflow2_mnist.py
# accuracy_1.pdf	    NOTES.txt	       test.pdf

# %%
# !du -h
# Out:
# 8.0K	./checkpoints/tf2_mnist-1_temp
# 1.4G	./checkpoints
# 120K	./.ipynb_checkpoints
# 1.4G	.

# %%
# !rm -r -f ./checkpoints/*

# %%
# !mpirun -n 1 python tensorflow2_mnist_hvd.py
# Out:
# [1668050669.981532] [thetagpu09:2538151:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# Epoch - 0, step #000000/000234	Loss: 2.312997
# Epoch - 0, step #000100/000234	Loss: 0.156629
# Epoch - 0, step #000200/000234	Loss: 0.180394
# E[0], train Loss: 0.272305, training Acc: 0.916, val loss: 0.063, val Acc: 0.980	 Time: 14.782 seconds
# Epoch - 1, step #000000/000234	Loss: 0.130646
# Epoch - 1, step #000100/000234	Loss: 0.175223
# Epoch - 1, step #000200/000234	Loss: 0.065241
# E[1], train Loss: 0.107048, training Acc: 0.968, val loss: 0.047, val Acc: 0.985	 Time: 10.040 seconds
# Epoch - 2, step #000000/000234	Loss: 0.059845
# Epoch - 2, step #000100/000234	Loss: 0.066601
# Epoch - 2, step #000200/000234	Loss: 0.061395
# E[2], train Loss: 0.088746, training Acc: 0.973, val loss: 0.039, val Acc: 0.987	 Time: 10.144 seconds
# ...

# %%
# !mpirun -n 2 python tensorflow2_mnist_hvd.py
# Out:
# [1668051027.854648] [thetagpu09:2546284:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668051027.854648] [thetagpu09:2546285:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# Epoch - 0, step #000000/000117	Loss: 2.315714
# Epoch - 0, step #000000/000117	Loss: 2.315714
# Epoch - 0, step #000100/000117	Loss: 2.303909
# Epoch - 0, step #000100/000117	Loss: 2.303909
# E[0], train Loss: 2.348922, training Acc: 0.111, val loss: 2.301, val Acc: 0.113	 Time: 12.994 seconds
# E[0], train Loss: 2.348922, training Acc: 0.111, val loss: 2.301, val Acc: 0.113	 Time: 10.857 seconds
# Epoch - 1, step #000000/000117	Loss: 2.303823
# Epoch - 1, step #000000/000117	Loss: 2.303823
# ...

# %%
## Unclear why it is not working, the -n 2 worked sometimes, 
## but sometimes it crasshed. 
# !mpirun -n 2 python tensorflow2_mnist_hvd_v2.py
# Out:
# [1668055984.991031] [thetagpu21:2600422:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668055984.991002] [thetagpu21:2600421:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# Epoch - 0, step #000000/000117	Loss: 2.300265
# Epoch - 0, step #000000/000117	Loss: 2.300265
# Epoch - 0, step #000100/000117	Loss: 0.194487
# Epoch - 0, step #000100/000117	Loss: 0.194487
# E[0], train Loss: 0.202509, training Acc: 0.941, val loss: 0.081, val Acc: 0.975	 Time: 11.407 seconds
# E[0], train Loss: 0.202509, training Acc: 0.941, val loss: 0.081, val Acc: 0.975	 Time: 20.843 seconds
# Epoch - 1, step #000000/000117	Loss: 0.174972
# Epoch - 1, step #000000/000117	Loss: 0.174972
# ...

# %%
## Unclear why it is not working. The -n 2 worked sometimes, 
## but sometimes it crasshed. 
# !mpirun -n 4 python tensorflow2_mnist_hvd_v2.py
# Out:
# [1668056783.909066] [thetagpu21:2617724:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668056783.909063] [thetagpu21:2617725:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668056783.944571] [thetagpu21:2617726:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668056783.962990] [thetagpu21:2617727:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# ...

# %%
## Unclear why it is not working. The -n 2 worked sometimes, 
## but sometimes it crasshed. 
# !mpirun -n 8 python tensorflow2_mnist_hvd_v2.py
# Out:
# [1668056835.831526] [thetagpu21:2619863:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668056835.831537] [thetagpu21:2619864:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668056835.898415] [thetagpu21:2619869:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# [1668056835.898502] [thetagpu21:2619868:0]     ucp_context.c:1518 UCX  WARN  UCP version is incompatible, required: 1.12, actual: 1.11 (release 2 /lus/theta-fs0/software/thetagpu/ucx/ucx-1.11.2_cuda-11.4_gcc-9.3.0/lib/libucp.so.0)
# ...

# %%
## plot Plot the training accuracy and validation accuracy 
## curve for different scales. (x-asix: epoch; y-axis: accuracy)
## Data from -n 1

data = []
data.append(['E[',0,'], train Loss: ',0.272305, 'training Acc: ',0.916, 'val loss: ',0.063, 'val Acc: ',0.980,'	 Time: ',14.782,' seconds'])
data.append(['E[',1,'], train Loss: ',0.107048, 'training Acc: ',0.968, 'val loss: ',0.047, 'val Acc: ',0.985,'	 Time: ',10.040,' seconds'])
data.append(['E[',2,'], train Loss: ',0.088746, 'training Acc: ',0.973, 'val loss: ',0.039, 'val Acc: ',0.987,'	 Time: ',10.144,' seconds'])
data.append(['E[',3,'], train Loss: ',0.080988, 'training Acc: ',0.976, 'val loss: ',0.035, 'val Acc: ',0.988,'	 Time: ',10.536,' seconds'])
data.append(['E[',4,'], train Loss: ',0.071524, 'training Acc: ',0.979, 'val loss: ',0.038, 'val Acc: ',0.988,'	 Time: ',10.461,' seconds'])
data.append(['E[',5,'], train Loss: ',0.070460, 'training Acc: ',0.979, 'val loss: ',0.036, 'val Acc: ',0.989,'	 Time: ',10.742,' seconds'])
data.append(['E[',6,'], train Loss: ',0.069385, 'training Acc: ',0.978, 'val loss: ',0.038, 'val Acc: ',0.988,'	 Time: ',11.268,' seconds'])
data.append(['E[',7,'], train Loss: ',0.063336, 'training Acc: ',0.980, 'val loss: ',0.033, 'val Acc: ',0.989,'	 Time: ',11.086,' seconds'])
data.append(['E[',8,'], train Loss: ',0.061313, 'training Acc: ',0.982, 'val loss: ',0.036, 'val Acc: ',0.989,'	 Time: ',11.213,' seconds'])
data.append(['E[',9,'], train Loss: ',0.061230, 'training Acc: ',0.981, 'val loss: ',0.039, 'val Acc: ',0.988,'	 Time: ',11.440,' seconds'])
data.append(['E[',10,'], train Loss:',0.059841, 'training Acc: ',0.982, 'val loss: ',0.044, 'val Acc: ',0.988,'	 Time: ',11.771,' seconds'])
data.append(['E[',11,'], train Loss:',0.058969, 'training Acc: ',0.982, 'val loss: ',0.034, 'val Acc: ',0.991,'	 Time: ',11.847,' seconds'])

import matplotlib.pyplot as plt
plt.title('mpirun -n 1 python tensorflow2_mnist_hvd.py',fontsize=15)
plt.xlabel(r'Epoch',fontsize=15)
plt.ylabel(r'Accuracy',fontsize=15)
x = []
y = []
for i in range(len(data)):
    x.append(data[i][1])
    y.append(data[i][5])
plt.plot(x,y,label='Training')

x = []
y = []
for i in range(len(data)):
    x.append(data[i][1])
    y.append(data[i][9])
plt.plot(x,y, label='validation')
plt.legend()

from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages('accuracy_1.pdf')
pp.savefig()
pp.close()

# %%
# !ls
# Out:
# 10113346.cobaltlog  checkpoints        tensorflow2_mnist_hvd.py
# 10113347.cobaltlog  EA_homework.ipynb  tensorflow2_mnist_hvd.py~
# 10113352.cobaltlog  metrics.dat        tensorflow2_mnist.py
# 10113416.cobaltlog  NOTES.txt	       test.pdf
# accuracy_1.pdf	    README.md

# %%
## plot Plot the training accuracy and validation accuracy 
## curve for different scales. (x-asix: epoch; y-axis: accuracy)
## Data from -n 2

data = []
data.append(['E[',0,'], train Loss: ',2.348922, 'training Acc: ',0.111, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',10.857,' seconds'])
data.append(['E[',1,'], train Loss: ',2.301502, 'training Acc: ',0.110, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',6.065 ,'seconds'])
data.append(['E[',2,'], train Loss: ',2.301669, 'training Acc: ',0.113, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',6.196 ,'seconds'])
data.append(['E[',3,'], train Loss: ',2.301683, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',10.428,' seconds'])
data.append(['E[',4,'], train Loss: ',2.301707, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',10.427,' seconds'])
data.append(['E[',5,'], train Loss: ',2.301399, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',6.159 ,'seconds'])
data.append(['E[',6,'], train Loss: ',2.301543, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',6.088 ,'seconds'])
data.append(['E[',7,'], train Loss: ',2.301459, 'training Acc: ',0.114, 'val loss: ',2.302, 'val Acc: ',0.113,'	 Time: ',10.460,' seconds'])
data.append(['E[',8,'], train Loss: ',2.301682, 'training Acc: ',0.111, 'val loss: ',2.302, 'val Acc: ',0.113,'	 Time: ',10.431,' seconds'])
data.append(['E[',9,'], train Loss: ',2.302030, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',6.375 ,'seconds'])
data.append(['E[',10,'], train Loss:',2.301767, 'training Acc: ',0.112, 'val loss: ',2.302, 'val Acc: ',0.113,'	 Time: ',10.496,' seconds'])
data.append(['E[',11,'], train Loss:',2.301818, 'training Acc: ',0.112, 'val loss: ',2.302, 'val Acc: ',0.103,'	 Time: ',10.418,' seconds'])
data.append(['E[',12,'], train Loss:',2.301768, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',10.518,' seconds'])
data.append(['E[',13,'], train Loss:',2.301574, 'training Acc: ',0.114, 'val loss: ',2.302, 'val Acc: ',0.113,'	 Time: ',6.451 ,'seconds'])
data.append(['E[',14,'], train Loss:',2.302010, 'training Acc: ',0.112, 'val loss: ',2.303, 'val Acc: ',0.103,'	 Time: ',10.430,' seconds'])
data.append(['E[',15,'], train Loss:',2.301760, 'training Acc: ',0.112, 'val loss: ',2.301, 'val Acc: ',0.113,'	 Time: ',10.456,' seconds'])

import matplotlib.pyplot as plt
plt.title('mpirun -n 2 python tensorflow2_mnist_hvd_v2.py',fontsize=15)
plt.xlabel(r'Epoch',fontsize=15)
plt.ylabel(r'Accuracy',fontsize=15)
x = []
y = []
for i in range(len(data)):
    x.append(data[i][1])
    y.append(data[i][5])
plt.plot(x,y,label='Training')

x = []
y = []
for i in range(len(data)):
    x.append(data[i][1])
    y.append(data[i][9])
plt.plot(x,y, label='validation')
plt.legend()

from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages('accuracy_2.pdf')
pp.savefig()
pp.close()

# %%
## plot Plot the training accuracy and validation accuracy 
## curve for different scales. (x-asix: epoch; y-axis: accuracy)
## Data from -n 2

data = []

data.append(['E[',0,'], train Loss: ',0.202509, 'training Acc: ',0.941, 'val loss: ',0.081, 'val Acc: ',0.975,'	 Time: ',11.407,' seconds'])
data.append(['E[',1,'], train Loss: ',0.180926, 'training Acc: ',0.957, 'val loss: ',0.059, 'val Acc: ',0.981,'	 Time: ',20.720,' seconds'])
data.append(['E[',2,'], train Loss: ',0.115901, 'training Acc: ',0.969, 'val loss: ',0.052, 'val Acc: ',0.984,'	 Time: ',10.494,' seconds'])
data.append(['E[',3,'], train Loss: ',0.120733, 'training Acc: ',0.961, 'val loss: ',0.044, 'val Acc: ',0.986,'	 Time: ',10.484,' seconds'])
data.append(['E[',4,'], train Loss: ',0.072275, 'training Acc: ',0.975, 'val loss: ',0.048, 'val Acc: ',0.985,'	 Time: ',20.721,' seconds'])
data.append(['E[',5,'], train Loss: ',0.095194, 'training Acc: ',0.971, 'val loss: ',0.039, 'val Acc: ',0.987,'	 Time: ',16.861,' seconds'])
data.append(['E[',6,'], train Loss: ',0.099832, 'training Acc: ',0.973, 'val loss: ',0.048, 'val Acc: ',0.985,'	 Time: ',6.904 ,'seconds'])
data.append(['E[',7,'], train Loss: ',0.109780, 'training Acc: ',0.967, 'val loss: ',0.044, 'val Acc: ',0.986,'	 Time: ',10.513,' seconds'])
data.append(['E[',8,'], train Loss: ',0.064161, 'training Acc: ',0.975, 'val loss: ',0.044, 'val Acc: ',0.988,'	 Time: ',6.797 ,'seconds'])
data.append(['E[',9,'], train Loss: ',0.106690, 'training Acc: ',0.971, 'val loss: ',0.046, 'val Acc: ',0.986,'	 Time: ',10.473,' seconds'])
data.append(['E[',10,'], train Loss:',0.046311, 'training Acc: ',0.979, 'val loss: ',0.045, 'val Acc: ',0.987,'	 Time: ',6.946 ,'seconds'])
data.append(['E[',11,'], train Loss:',0.086258, 'training Acc: ',0.969, 'val loss: ',0.051, 'val Acc: ',0.986,'	 Time: ',7.018 ,'seconds'])
data.append(['E[',12,'], train Loss:',0.053252, 'training Acc: ',0.982, 'val loss: ',0.053, 'val Acc: ',0.986,'	 Time: ',10.512,' seconds'])
data.append(['E[',13,'], train Loss:',0.127080, 'training Acc: ',0.969, 'val loss: ',0.039, 'val Acc: ',0.988,'	 Time: ',7.219 ,'seconds'])
data.append(['E[',14,'], train Loss:',0.045701, 'training Acc: ',0.977, 'val loss: ',0.052, 'val Acc: ',0.986,'	 Time: ',7.286 ,'seconds'])
data.append(['E[',15,'], train Loss:',0.085518, 'training Acc: ',0.971, 'val loss: ',0.045, 'val Acc: ',0.987,'	 Time: ',7.416 ,'seconds'])

import matplotlib.pyplot as plt
plt.title('mpirun -n 2 python tensorflow2_mnist_hvd_v2.py',fontsize=15)
plt.xlabel(r'Epoch',fontsize=15)
plt.ylabel(r'Accuracy',fontsize=15)
x = []
y = []
for i in range(len(data)):
    x.append(data[i][1])
    y.append(data[i][5])
plt.plot(x,y,label='Training')

x = []
y = []
for i in range(len(data)):
    x.append(data[i][1])
    y.append(data[i][9])
plt.plot(x,y, label='validation')
plt.legend()

from matplotlib.backends.backend_pdf import PdfPages
pp = PdfPages('accuracy_2.pdf')
pp.savefig()
pp.close()
